# %% [markdown]
# Now that we have all the stats data downloaded from nflverse and cleaned, we'll load games, seasons, players into 3 tables in SQLlite

# %%
import pandas as pd
import sqlite3
import os
from paths import (
    PLAYERS_CSV,
    GAMES_CSV,
    SEASONS_CSV,
    SQLITE_DB_PATH
)

# -----------------------------
# Load CSVs
# -----------------------------
df_players = pd.read_csv(PLAYERS_CSV)
df_games = pd.read_csv(GAMES_CSV)
df_seasons = pd.read_csv(SEASONS_CSV)

print("✅ Loaded CSVs")
print("Players:", df_players.shape, "| Games:", df_games.shape, "| Seasons:", df_seasons.shape)

# -----------------------------
# Write to SQLite
# -----------------------------
os.makedirs(os.path.dirname(SQLITE_DB_PATH), exist_ok=True)
conn = sqlite3.connect(SQLITE_DB_PATH)

df_players.to_sql("players", conn, if_exists="replace", index=False)
df_games.to_sql("games", conn, if_exists="replace", index=False)
df_seasons.to_sql("seasons", conn, if_exists="replace", index=False)

conn.close()
print(f"✅ Saved all 3 tables to {SQLITE_DB_PATH}")
# Out:
# ✅ Loaded CSVs
# Players: (11898, 113) | Games: (104, 47) | Seasons: (6, 42)
# ✅ Saved all 3 tables to c:\Users\250331\Documents\GenAI Projects\EaglesGPT\data\stats.sqlite
